# %% [markdown]
# Background
# In quality control processes, especially when dealing with high-value items, destructive sampling is a necessary but costly method to ensure product quality. The test to determine whether an item meets the quality standards destroys the item, leading to the requirement of small sample sizes due to cost constraints.
# Scenario
# A manufacturer of print-heads for personal computers is interested in estimating the mean durability of their print-heads in terms of the number of characters printed before failure. To assess this, the manufacturer conducts a study on a small sample of print-heads due to the destructive nature of the testing process.
# Data
# A total of 15 print-heads were randomly selected and tested until failure. The durability of each print-head (in millions of characters) was recorded as follows:
# 1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29

# %% [markdown]
# Assignment Tasks
# a. Build 99% Confidence Interval Using Sample Standard Deviation
# Assuming the sample is representative of the population, construct a 99% confidence interval for the mean number of characters printed before the print-head fails using the sample standard deviation. Explain the steps you take and the rationale behind using the t-distribution for this task.

# %%
import numpy as np
from scipy import stats

# %%
#Data
data = [1.13, 1.55, 1.43, 0.92, 1.25,1.36, 1.32, 0.85, 1.07, 1.48,1.20, 1.33, 1.18, 1.22, 1.29]
print(data)
# Out:
# [1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.2, 1.33, 1.18, 1.22, 1.29]

# %%
#Calculate Sample Mean
n = len(data)
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
print("Sample Size:", n)
print("Sample Mean:", sample_mean)
print("Sample Standard Deviation:", sample_std)
# Out:
# Sample Size: 15
# Sample Mean: 1.2386666666666666
# Sample Standard Deviation: 0.19316412956959936

# %%
#Set Confidence Level
confidence = 0.99
alpha = 1 - confidence
print(alpha)
# Out:
# 0.010000000000000009

# %%
#calculate t-critical
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)
print("t-Critical Value:", t_critical)
# Out:
# t-Critical Value: 2.976842734370834

# %%
#Calculate Margin Error
margin_error = t_critical * (sample_std / np.sqrt(n))
print("Margin of Error:", margin_error)
# Out:
# Margin of Error: 0.14846932822817596

# %%
#Calculate the 99% confidence
lower_limit = sample_mean - margin_error
upper_limit = sample_mean + margin_error
print("99% Confidence Interval:")
print(f"({lower_limit:.4f}, {upper_limit:.4f})")
# Out:
# 99% Confidence Interval:
# (1.0902, 1.3871)

# %% [markdown]
# Explanation:
# Why is the t-distribution used?
# The sample size is small (n = 15).
# The population standard deviation (σ) is unknown.
# Therefore, the Student's t-distribution is more appropriate than the normal (Z) distribution because it accounts for the additional uncertainty introduced by estimating the population standard deviation from the sample.

# %% [markdown]
# b. Build 99% Confidence Interval Using Known Population Standard Deviation
# If it were known that the population standard deviation is 0.2 million characters, construct a 99% confidence interval for the mean number of characters printed before failure.

# %% [markdown]
# Import Libraries(Completed in Task A)
# Enter the Sample Data(Completed in Task A)
# Calculate the Sample Mean(Completed in above Task A)
# Calculate the Margin of Error(completed in Task A)
# Calculate the 99% Confidence Interval(completed in Task A)

# %%
#Population Standard Deviation
sigma = 0.2
confidence = 0.99
alpha = 1 - confidence
print(alpha)
# Out:
# 0.010000000000000009

# %%
#calculate z-critical
z_critical = stats.norm.ppf(1 - alpha/2)
print("Z-Critical Value:", z_critical)
# Out:
# Z-Critical Value: 2.5758293035489004
